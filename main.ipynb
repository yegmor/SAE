# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
labels = np.load('data/labels/OASIS_0009.npz')
labels = np.array(labels['vol_data'])
labels.shape
# Out:
# (160, 192, 224)

# %%
plt.plot(labels[50])
# Out:
# [<matplotlib.lines.Line2D at 0x210aef3c610>,
#  <matplotlib.lines.Line2D at 0x210aef3c670>,
#  <matplotlib.lines.Line2D at 0x210aef3c6a0>,
#  <matplotlib.lines.Line2D at 0x210aef3c790>,
#  <matplotlib.lines.Line2D at 0x210aef3c880>,
#  <matplotlib.lines.Line2D at 0x210a6d08730>,
#  <matplotlib.lines.Line2D at 0x210ab308fd0>,
#  <matplotlib.lines.Line2D at 0x210aeeafd90>,
#  <matplotlib.lines.Line2D at 0x210aeeadb70>,
#  <matplotlib.lines.Line2D at 0x210aec57e80>,
#  <matplotlib.lines.Line2D at 0x210aef3ccd0>,
#  <matplotlib.lines.Line2D at 0x210aef3c640>,
#  <matplotlib.lines.Line2D at 0x210aef3cdc0>,
#  <matplotlib.lines.Line2D at 0x210aef3cf70>,
#  <matplotlib.lines.Line2D at 0x210aef3d060>,
#  <matplotlib.lines.Line2D at 0x210aef3d150>,
#  <matplotlib.lines.Line2D at 0x210aef3d240>,
#  <matplotlib.lines.Line2D at 0x210aef3d330>,
#  <matplotlib.lines.Line2D at 0x210aef3d420>,
#  <matplotlib.lines.Line2D at 0x210aef3d510>,
#  <matplotlib.lines.Line2D at 0x210aef3d600>,
#  <matplotlib.lines.Line2D at 0x210aef3d6f0>,
#  <matplotlib.lines.Line2D at 0x210aef3d7e0>,
#  <matplotlib.lines.Line2D at 0x210aef3d8d0>,
#  <matplotlib.lines.Line2D at 0x210aef3d9c0>,
#  <matplotlib.lines.Line2D at 0x210aef3dab0>,
#  <matplotlib.lines.Line2D at 0x210aef3dba0>,
#  <matplotlib.lines.Line2D at 0x210aef3dc90>,
#  <matplotlib.lines.Line2D at 0x210aef3dd80>,
#  <matplotlib.lines.Line2D at 0x210aef3de70>,
#  <matplotlib.lines.Line2D at 0x210aef3df60>,
#  <matplotlib.lines.Line2D at 0x210aef3e050>,
#  <matplotlib.lines.Line2D at 0x210aef3e140>,
#  <matplotlib.lines.Line2D at 0x210aef3e230>,
#  <matplotlib.lines.Line2D at 0x210aef3e320>,
#  <matplotlib.lines.Line2D at 0x210aef3e410>,
#  <matplotlib.lines.Line2D at 0x210aef3e500>,
#  <matplotlib.lines.Line2D at 0x210aef3e5f0>,
#  <matplotlib.lines.Line2D at 0x210aef3e6e0>,
#  <matplotlib.lines.Line2D at 0x210aef3e7d0>,
#  <matplotlib.lines.Line2D at 0x210aef3e8c0>,
#  <matplotlib.lines.Line2D at 0x210aef3e9b0>,
#  <matplotlib.lines.Line2D at 0x210aef3eaa0>,
#  <matplotlib.lines.Line2D at 0x210aef3eb90>,
#  <matplotlib.lines.Line2D at 0x210aef3ec80>,
#  <matplotlib.lines.Line2D at 0x210aef3ed70>,
#  <matplotlib.lines.Line2D at 0x210aef3ee60>,
#  <matplotlib.lines.Line2D at 0x210aef3ef50>,
#  <matplotlib.lines.Line2D at 0x210aef3f040>,
#  <matplotlib.lines.Line2D at 0x210aef3f130>,
#  <matplotlib.lines.Line2D at 0x210aef3f220>,
#  <matplotlib.lines.Line2D at 0x210aef3f310>,
#  <matplotlib.lines.Line2D at 0x210aef3f400>,
#  <matplotlib.lines.Line2D at 0x210aef3f4f0>,
#  <matplotlib.lines.Line2D at 0x210aef3f5e0>,
#  <matplotlib.lines.Line2D at 0x210aef3f6d0>,
#  <matplotlib.lines.Line2D at 0x210aef3f7c0>,
#  <matplotlib.lines.Line2D at 0x210aef3f8b0>,
#  <matplotlib.lines.Line2D at 0x210aef3f9a0>,
#  <matplotlib.lines.Line2D at 0x210aef3fa90>,
#  <matplotlib.lines.Line2D at 0x210aef3fb80>,
#  <matplotlib.lines.Line2D at 0x210aef3fc70>,
#  <matplotlib.lines.Line2D at 0x210aef3fd60>,
#  <matplotlib.lines.Line2D at 0x210aef3fe50>,
#  <matplotlib.lines.Line2D at 0x210aef3ff40>,
#  <matplotlib.lines.Line2D at 0x210aef58070>,
#  <matplotlib.lines.Line2D at 0x210aef58160>,
#  <matplotlib.lines.Line2D at 0x210aef58250>,
#  <matplotlib.lines.Line2D at 0x210aef58340>,
#  <matplotlib.lines.Line2D at 0x210aef58430>,
#  <matplotlib.lines.Line2D at 0x210aef58520>,
#  <matplotlib.lines.Line2D at 0x210aef58610>,
#  <matplotlib.lines.Line2D at 0x210aef58700>,
#  <matplotlib.lines.Line2D at 0x210aef587f0>,
#  <matplotlib.lines.Line2D at 0x210aef588e0>,
#  <matplotlib.lines.Line2D at 0x210aef589d0>,
#  <matplotlib.lines.Line2D at 0x210aef58ac0>,
#  <matplotlib.lines.Line2D at 0x210aef58bb0>,
#  <matplotlib.lines.Line2D at 0x210aef58ca0>,
#  <matplotlib.lines.Line2D at 0x210aef58d90>,
#  <matplotlib.lines.Line2D at 0x210aef58e80>,
#  <matplotlib.lines.Line2D at 0x210aef58f70>,
#  <matplotlib.lines.Line2D at 0x210aef59060>,
#  <matplotlib.lines.Line2D at 0x210aef59150>,
#  <matplotlib.lines.Line2D at 0x210aef59240>,
#  <matplotlib.lines.Line2D at 0x210aef59330>,
#  <matplotlib.lines.Line2D at 0x210aef59420>,
#  <matplotlib.lines.Line2D at 0x210aef59510>,
#  <matplotlib.lines.Line2D at 0x210aef59600>,
#  <matplotlib.lines.Line2D at 0x210aef596f0>,
#  <matplotlib.lines.Line2D at 0x210aef597e0>,
#  <matplotlib.lines.Line2D at 0x210aef598d0>,
#  <matplotlib.lines.Line2D at 0x210aef599c0>,
#  <matplotlib.lines.Line2D at 0x210aef59ab0>,
#  <matplotlib.lines.Line2D at 0x210aef59ba0>,
#  <matplotlib.lines.Line2D at 0x210aef59c90>,
#  <matplotlib.lines.Line2D at 0x210aef59d80>,
#  <matplotlib.lines.Line2D at 0x210aef59e70>,
#  <matplotlib.lines.Line2D at 0x210aef59f60>,
#  <matplotlib.lines.Line2D at 0x210aef5a050>,
#  <matplotlib.lines.Line2D at 0x210aef5a140>,
#  <matplotlib.lines.Line2D at 0x210aef5a230>,
#  <matplotlib.lines.Line2D at 0x210aef5a320>,
#  <matplotlib.lines.Line2D at 0x210aef5a410>,
#  <matplotlib.lines.Line2D at 0x210aef5a500>,
#  <matplotlib.lines.Line2D at 0x210aef5a5f0>,
#  <matplotlib.lines.Line2D at 0x210aef5a6e0>,
#  <matplotlib.lines.Line2D at 0x210aef5a7d0>,
#  <matplotlib.lines.Line2D at 0x210aef5a8c0>,
#  <matplotlib.lines.Line2D at 0x210aef5a9b0>,
#  <matplotlib.lines.Line2D at 0x210aef5aaa0>,
#  <matplotlib.lines.Line2D at 0x210aef5ab90>,
#  <matplotlib.lines.Line2D at 0x210aef5ac80>,
#  <matplotlib.lines.Line2D at 0x210aef5ad70>,
#  <matplotlib.lines.Line2D at 0x210aef5ae60>,
#  <matplotlib.lines.Line2D at 0x210aef5af50>,
#  <matplotlib.lines.Line2D at 0x210aef5b040>,
#  <matplotlib.lines.Line2D at 0x210aef5b130>,
#  <matplotlib.lines.Line2D at 0x210aef5b220>,
#  <matplotlib.lines.Line2D at 0x210aef5b310>,
#  <matplotlib.lines.Line2D at 0x210aef5b400>,
#  <matplotlib.lines.Line2D at 0x210aef5b4f0>,
#  <matplotlib.lines.Line2D at 0x210aef5b5e0>,
#  <matplotlib.lines.Line2D at 0x210aef5b6d0>,
#  <matplotlib.lines.Line2D at 0x210aef5b7c0>,
#  <matplotlib.lines.Line2D at 0x210aef5b8b0>,
#  <matplotlib.lines.Line2D at 0x210aef5b9a0>,
#  <matplotlib.lines.Line2D at 0x210aef5ba90>,
#  <matplotlib.lines.Line2D at 0x210aef5bb80>,
#  <matplotlib.lines.Line2D at 0x210aef5bc70>,
#  <matplotlib.lines.Line2D at 0x210aef5bd60>,
#  <matplotlib.lines.Line2D at 0x210aef5be50>,
#  <matplotlib.lines.Line2D at 0x210aef5bf40>,
#  <matplotlib.lines.Line2D at 0x210aef70070>,
#  <matplotlib.lines.Line2D at 0x210aef70160>,
#  <matplotlib.lines.Line2D at 0x210aef70250>,
#  <matplotlib.lines.Line2D at 0x210aef70340>,
#  <matplotlib.lines.Line2D at 0x210aef70430>,
#  <matplotlib.lines.Line2D at 0x210aef70520>,
#  <matplotlib.lines.Line2D at 0x210aef70610>,
#  <matplotlib.lines.Line2D at 0x210aef70700>,
#  <matplotlib.lines.Line2D at 0x210aef707f0>,
#  <matplotlib.lines.Line2D at 0x210aef708e0>,
#  <matplotlib.lines.Line2D at 0x210aef709d0>,
#  <matplotlib.lines.Line2D at 0x210aef70ac0>,
#  <matplotlib.lines.Line2D at 0x210aef70bb0>,
#  <matplotlib.lines.Line2D at 0x210aef70ca0>,
#  <matplotlib.lines.Line2D at 0x210aef70d90>,
#  <matplotlib.lines.Line2D at 0x210aef70e80>,
#  <matplotlib.lines.Line2D at 0x210aef70f70>,
#  <matplotlib.lines.Line2D at 0x210aef71060>,
#  <matplotlib.lines.Line2D at 0x210aef71150>,
#  <matplotlib.lines.Line2D at 0x210aef71240>,
#  <matplotlib.lines.Line2D at 0x210aef71330>,
#  <matplotlib.lines.Line2D at 0x210aef71420>,
#  <matplotlib.lines.Line2D at 0x210aef71510>,
#  <matplotlib.lines.Line2D at 0x210aef71600>,
#  <matplotlib.lines.Line2D at 0x210aef716f0>,
#  <matplotlib.lines.Line2D at 0x210aef717e0>,
#  <matplotlib.lines.Line2D at 0x210aef718d0>,
#  <matplotlib.lines.Line2D at 0x210aef719c0>,
#  <matplotlib.lines.Line2D at 0x210aef71ab0>,
#  <matplotlib.lines.Line2D at 0x210aef71ba0>,
#  <matplotlib.lines.Line2D at 0x210aef71c90>,
#  <matplotlib.lines.Line2D at 0x210aef71d80>,
#  <matplotlib.lines.Line2D at 0x210aef71e70>,
#  <matplotlib.lines.Line2D at 0x210aef71f60>,
#  <matplotlib.lines.Line2D at 0x210aef72050>,
#  <matplotlib.lines.Line2D at 0x210aef72140>,
#  <matplotlib.lines.Line2D at 0x210aef72230>,
#  <matplotlib.lines.Line2D at 0x210aef72320>,
#  <matplotlib.lines.Line2D at 0x210aef72410>,
#  <matplotlib.lines.Line2D at 0x210aef72500>,
#  <matplotlib.lines.Line2D at 0x210aef725f0>,
#  <matplotlib.lines.Line2D at 0x210aef726e0>,
#  <matplotlib.lines.Line2D at 0x210aef727d0>,
#  <matplotlib.lines.Line2D at 0x210aef728c0>,
#  <matplotlib.lines.Line2D at 0x210aef729b0>,
#  <matplotlib.lines.Line2D at 0x210aef72aa0>,
#  <matplotlib.lines.Line2D at 0x210aef72b90>,
#  <matplotlib.lines.Line2D at 0x210aef72c80>,
#  <matplotlib.lines.Line2D at 0x210aef72d70>,
#  <matplotlib.lines.Line2D at 0x210aef72e60>,
#  <matplotlib.lines.Line2D at 0x210aef72f50>,
#  <matplotlib.lines.Line2D at 0x210aef73040>,
#  <matplotlib.lines.Line2D at 0x210aef73130>,
#  <matplotlib.lines.Line2D at 0x210aef73220>,
#  <matplotlib.lines.Line2D at 0x210aef73310>,
#  <matplotlib.lines.Line2D at 0x210aef73400>,
#  <matplotlib.lines.Line2D at 0x210aef734f0>,
#  <matplotlib.lines.Line2D at 0x210aef735e0>,
#  <matplotlib.lines.Line2D at 0x210aef736d0>,
#  <matplotlib.lines.Line2D at 0x210aef737c0>,
#  <matplotlib.lines.Line2D at 0x210aef738b0>,
#  <matplotlib.lines.Line2D at 0x210aef739a0>,
#  <matplotlib.lines.Line2D at 0x210aef73a90>,
#  <matplotlib.lines.Line2D at 0x210aef73b80>,
#  <matplotlib.lines.Line2D at 0x210aef73c70>,
#  <matplotlib.lines.Line2D at 0x210aef73d60>,
#  <matplotlib.lines.Line2D at 0x210aef73e50>,
#  <matplotlib.lines.Line2D at 0x210aef73f40>,
#  <matplotlib.lines.Line2D at 0x210aef88070>,
#  <matplotlib.lines.Line2D at 0x210aef88160>,
#  <matplotlib.lines.Line2D at 0x210aef88250>,
#  <matplotlib.lines.Line2D at 0x210aef88340>,
#  <matplotlib.lines.Line2D at 0x210aef88430>,
#  <matplotlib.lines.Line2D at 0x210aef88520>,
#  <matplotlib.lines.Line2D at 0x210aef88610>,
#  <matplotlib.lines.Line2D at 0x210aef88700>,
#  <matplotlib.lines.Line2D at 0x210aef887f0>,
#  <matplotlib.lines.Line2D at 0x210aef888e0>,
#  <matplotlib.lines.Line2D at 0x210aef889d0>,
#  <matplotlib.lines.Line2D at 0x210aef88ac0>,
#  <matplotlib.lines.Line2D at 0x210aef88bb0>,
#  <matplotlib.lines.Line2D at 0x210aef88ca0>,
#  <matplotlib.lines.Line2D at 0x210aef88d90>,
#  <matplotlib.lines.Line2D at 0x210aef88e80>,
#  <matplotlib.lines.Line2D at 0x210aef88f70>,
#  <matplotlib.lines.Line2D at 0x210aef89060>,
#  <matplotlib.lines.Line2D at 0x210aef89150>,
#  <matplotlib.lines.Line2D at 0x210aef89240>,
#  <matplotlib.lines.Line2D at 0x210aef89330>,
#  <matplotlib.lines.Line2D at 0x210aef89420>,
#  <matplotlib.lines.Line2D at 0x210aef89510>]

# %%
np.where(labels==13)
# Out:
# (array([ 91,  91,  91, ..., 108, 108, 108], dtype=int64),
#  array([ 97,  97,  97, ..., 102, 102, 102], dtype=int64),
#  array([123, 124, 125, ..., 112, 113, 114], dtype=int64))

# %%
vols = np.load('data/vols/OASIS_0009.npz')
vols = np.array(vols['vol_data'])
vols.shape
# Out:
# (160, 192, 224)

# %%
vols_new = 255*vols

# %%
vols_123.shape
# Out:
# (192, 224)

# %%
vols_123 = 255*vols
plt.plot(vols_123)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 vols_123 = 255*vols
# ----> 2 plt.plot(vols_123)
#
# File ~\Documents\SAE\venv\lib\site-packages\matplotlib\pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\Documents\SAE\venv\lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~\Documents\SAE\venv\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\Documents\SAE\venv\lib\site-packages\matplotlib\axes\_base.py:507, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
# --> 507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#     509 if x.ndim == 1:
#     510     x = x[:, np.newaxis]
#
# ValueError: x and y can be no greater than 2D, but have shapes (160,) and (160, 192, 224)

# %%
np.average(vols)
# Out:
# 0.07962961462254177

# %%
plt.plot(vols[0])
# Out:
# [<matplotlib.lines.Line2D at 0x210a8f998d0>,
#  <matplotlib.lines.Line2D at 0x210a8f99720>,
#  <matplotlib.lines.Line2D at 0x210a8f99840>,
#  <matplotlib.lines.Line2D at 0x210a7275ff0>,
#  <matplotlib.lines.Line2D at 0x210a8ea0640>,
#  <matplotlib.lines.Line2D at 0x210ab14d330>,
#  <matplotlib.lines.Line2D at 0x210ab14c580>,
#  <matplotlib.lines.Line2D at 0x210ab14e050>,
#  <matplotlib.lines.Line2D at 0x210ab14e140>,
#  <matplotlib.lines.Line2D at 0x210ab14e230>,
#  <matplotlib.lines.Line2D at 0x210a8f99900>,
#  <matplotlib.lines.Line2D at 0x210ab14e320>,
#  <matplotlib.lines.Line2D at 0x210ab14e410>,
#  <matplotlib.lines.Line2D at 0x210ab14e5c0>,
#  <matplotlib.lines.Line2D at 0x210ab14e6b0>,
#  <matplotlib.lines.Line2D at 0x210ab14e7a0>,
#  <matplotlib.lines.Line2D at 0x210ab14e890>,
#  <matplotlib.lines.Line2D at 0x210ab14e980>,
#  <matplotlib.lines.Line2D at 0x210ab14ea70>,
#  <matplotlib.lines.Line2D at 0x210ab14eb60>,
#  <matplotlib.lines.Line2D at 0x210ab14ec50>,
#  <matplotlib.lines.Line2D at 0x210ab14ed40>,
#  <matplotlib.lines.Line2D at 0x210ab14ee30>,
#  <matplotlib.lines.Line2D at 0x210ab14ef20>,
#  <matplotlib.lines.Line2D at 0x210ab14f010>,
#  <matplotlib.lines.Line2D at 0x210ab14f100>,
#  <matplotlib.lines.Line2D at 0x210ab14f1f0>,
#  <matplotlib.lines.Line2D at 0x210ab14f2e0>,
#  <matplotlib.lines.Line2D at 0x210ab14f3d0>,
#  <matplotlib.lines.Line2D at 0x210ab14f4c0>,
#  <matplotlib.lines.Line2D at 0x210ab14f5b0>,
#  <matplotlib.lines.Line2D at 0x210ab14f6a0>,
#  <matplotlib.lines.Line2D at 0x210ab14f790>,
#  <matplotlib.lines.Line2D at 0x210ab14f880>,
#  <matplotlib.lines.Line2D at 0x210ab14f970>,
#  <matplotlib.lines.Line2D at 0x210ab14fa60>,
#  <matplotlib.lines.Line2D at 0x210ab14fb50>,
#  <matplotlib.lines.Line2D at 0x210ab14fc40>,
#  <matplotlib.lines.Line2D at 0x210ab14fd30>,
#  <matplotlib.lines.Line2D at 0x210ab14fe20>,
#  <matplotlib.lines.Line2D at 0x210ab14ff10>,
#  <matplotlib.lines.Line2D at 0x210ab170040>,
#  <matplotlib.lines.Line2D at 0x210ab170130>,
#  <matplotlib.lines.Line2D at 0x210ab170220>,
#  <matplotlib.lines.Line2D at 0x210ab170310>,
#  <matplotlib.lines.Line2D at 0x210ab170400>,
#  <matplotlib.lines.Line2D at 0x210ab1704f0>,
#  <matplotlib.lines.Line2D at 0x210ab1705e0>,
#  <matplotlib.lines.Line2D at 0x210ab1706d0>,
#  <matplotlib.lines.Line2D at 0x210ab1707c0>,
#  <matplotlib.lines.Line2D at 0x210ab1708b0>,
#  <matplotlib.lines.Line2D at 0x210ab1709a0>,
#  <matplotlib.lines.Line2D at 0x210ab170a90>,
#  <matplotlib.lines.Line2D at 0x210ab170b80>,
#  <matplotlib.lines.Line2D at 0x210ab170c70>,
#  <matplotlib.lines.Line2D at 0x210ab170d60>,
#  <matplotlib.lines.Line2D at 0x210ab170e50>,
#  <matplotlib.lines.Line2D at 0x210ab170f40>,
#  <matplotlib.lines.Line2D at 0x210ab171030>,
#  <matplotlib.lines.Line2D at 0x210ab171120>,
#  <matplotlib.lines.Line2D at 0x210ab171210>,
#  <matplotlib.lines.Line2D at 0x210ab171300>,
#  <matplotlib.lines.Line2D at 0x210ab1713f0>,
#  <matplotlib.lines.Line2D at 0x210ab1714e0>,
#  <matplotlib.lines.Line2D at 0x210ab1715d0>,
#  <matplotlib.lines.Line2D at 0x210ab1716c0>,
#  <matplotlib.lines.Line2D at 0x210ab1717b0>,
#  <matplotlib.lines.Line2D at 0x210ab1718a0>,
#  <matplotlib.lines.Line2D at 0x210ab171990>,
#  <matplotlib.lines.Line2D at 0x210ab171a80>,
#  <matplotlib.lines.Line2D at 0x210ab171b70>,
#  <matplotlib.lines.Line2D at 0x210ab171c60>,
#  <matplotlib.lines.Line2D at 0x210ab171d50>,
#  <matplotlib.lines.Line2D at 0x210ab171e70>,
#  <matplotlib.lines.Line2D at 0x210ab171f60>,
#  <matplotlib.lines.Line2D at 0x210ab172050>,
#  <matplotlib.lines.Line2D at 0x210ab172140>,
#  <matplotlib.lines.Line2D at 0x210ab172230>,
#  <matplotlib.lines.Line2D at 0x210ab172320>,
#  <matplotlib.lines.Line2D at 0x210ab172410>,
#  <matplotlib.lines.Line2D at 0x210ab172500>,
#  <matplotlib.lines.Line2D at 0x210ab1725f0>,
#  <matplotlib.lines.Line2D at 0x210ab1726e0>,
#  <matplotlib.lines.Line2D at 0x210ab1727d0>,
#  <matplotlib.lines.Line2D at 0x210ab1728c0>,
#  <matplotlib.lines.Line2D at 0x210ab1729b0>,
#  <matplotlib.lines.Line2D at 0x210ab172aa0>,
#  <matplotlib.lines.Line2D at 0x210ab172b90>,
#  <matplotlib.lines.Line2D at 0x210ab172c80>,
#  <matplotlib.lines.Line2D at 0x210ab172d70>,
#  <matplotlib.lines.Line2D at 0x210ab172e60>,
#  <matplotlib.lines.Line2D at 0x210ab172f50>,
#  <matplotlib.lines.Line2D at 0x210ab173040>,
#  <matplotlib.lines.Line2D at 0x210ab173130>,
#  <matplotlib.lines.Line2D at 0x210ab173220>,
#  <matplotlib.lines.Line2D at 0x210ab173310>,
#  <matplotlib.lines.Line2D at 0x210ab173400>,
#  <matplotlib.lines.Line2D at 0x210ab1734f0>,
#  <matplotlib.lines.Line2D at 0x210ab1735e0>,
#  <matplotlib.lines.Line2D at 0x210ab1736d0>,
#  <matplotlib.lines.Line2D at 0x210ab1737c0>,
#  <matplotlib.lines.Line2D at 0x210ab1738b0>,
#  <matplotlib.lines.Line2D at 0x210ab1739a0>,
#  <matplotlib.lines.Line2D at 0x210ab173a90>,
#  <matplotlib.lines.Line2D at 0x210ab173b80>,
#  <matplotlib.lines.Line2D at 0x210ab173c70>,
#  <matplotlib.lines.Line2D at 0x210ab173d60>,
#  <matplotlib.lines.Line2D at 0x210ab173e50>,
#  <matplotlib.lines.Line2D at 0x210ab173f40>,
#  <matplotlib.lines.Line2D at 0x210ab190070>,
#  <matplotlib.lines.Line2D at 0x210ab190160>,
#  <matplotlib.lines.Line2D at 0x210ab190250>,
#  <matplotlib.lines.Line2D at 0x210ab190340>,
#  <matplotlib.lines.Line2D at 0x210ab190430>,
#  <matplotlib.lines.Line2D at 0x210ab190520>,
#  <matplotlib.lines.Line2D at 0x210ab190610>,
#  <matplotlib.lines.Line2D at 0x210ab190700>,
#  <matplotlib.lines.Line2D at 0x210ab1907f0>,
#  <matplotlib.lines.Line2D at 0x210ab1908e0>,
#  <matplotlib.lines.Line2D at 0x210ab1909d0>,
#  <matplotlib.lines.Line2D at 0x210ab190ac0>,
#  <matplotlib.lines.Line2D at 0x210ab190bb0>,
#  <matplotlib.lines.Line2D at 0x210ab190ca0>,
#  <matplotlib.lines.Line2D at 0x210ab190d90>,
#  <matplotlib.lines.Line2D at 0x210ab190e80>,
#  <matplotlib.lines.Line2D at 0x210ab190f70>,
#  <matplotlib.lines.Line2D at 0x210ab191060>,
#  <matplotlib.lines.Line2D at 0x210ab191150>,
#  <matplotlib.lines.Line2D at 0x210ab191240>,
#  <matplotlib.lines.Line2D at 0x210ab191330>,
#  <matplotlib.lines.Line2D at 0x210ab191420>,
#  <matplotlib.lines.Line2D at 0x210ab191510>,
#  <matplotlib.lines.Line2D at 0x210ab191600>,
#  <matplotlib.lines.Line2D at 0x210ab1916f0>,
#  <matplotlib.lines.Line2D at 0x210ab1917e0>,
#  <matplotlib.lines.Line2D at 0x210ab1918d0>,
#  <matplotlib.lines.Line2D at 0x210ab1919c0>,
#  <matplotlib.lines.Line2D at 0x210ab191ab0>,
#  <matplotlib.lines.Line2D at 0x210ab191ba0>,
#  <matplotlib.lines.Line2D at 0x210ab191c90>,
#  <matplotlib.lines.Line2D at 0x210ab191d80>,
#  <matplotlib.lines.Line2D at 0x210ab191e70>,
#  <matplotlib.lines.Line2D at 0x210ab191f60>,
#  <matplotlib.lines.Line2D at 0x210ab192050>,
#  <matplotlib.lines.Line2D at 0x210ab192140>,
#  <matplotlib.lines.Line2D at 0x210ab192230>,
#  <matplotlib.lines.Line2D at 0x210ab192320>,
#  <matplotlib.lines.Line2D at 0x210ab192410>,
#  <matplotlib.lines.Line2D at 0x210ab192500>,
#  <matplotlib.lines.Line2D at 0x210ab1925f0>,
#  <matplotlib.lines.Line2D at 0x210ab1926e0>,
#  <matplotlib.lines.Line2D at 0x210ab1927d0>,
#  <matplotlib.lines.Line2D at 0x210ab1928c0>,
#  <matplotlib.lines.Line2D at 0x210ab1929b0>,
#  <matplotlib.lines.Line2D at 0x210ab192aa0>,
#  <matplotlib.lines.Line2D at 0x210ab192b90>,
#  <matplotlib.lines.Line2D at 0x210ab192c80>,
#  <matplotlib.lines.Line2D at 0x210ab192d70>,
#  <matplotlib.lines.Line2D at 0x210ab192e60>,
#  <matplotlib.lines.Line2D at 0x210ab192f50>,
#  <matplotlib.lines.Line2D at 0x210ab193040>,
#  <matplotlib.lines.Line2D at 0x210ab193130>,
#  <matplotlib.lines.Line2D at 0x210ab193220>,
#  <matplotlib.lines.Line2D at 0x210ab193310>,
#  <matplotlib.lines.Line2D at 0x210ab193400>,
#  <matplotlib.lines.Line2D at 0x210ab1934f0>,
#  <matplotlib.lines.Line2D at 0x210ab1935e0>,
#  <matplotlib.lines.Line2D at 0x210ab1936d0>,
#  <matplotlib.lines.Line2D at 0x210ab1937c0>,
#  <matplotlib.lines.Line2D at 0x210ab1938b0>,
#  <matplotlib.lines.Line2D at 0x210ab1939a0>,
#  <matplotlib.lines.Line2D at 0x210ab193a90>,
#  <matplotlib.lines.Line2D at 0x210ab193b80>,
#  <matplotlib.lines.Line2D at 0x210ab193c70>,
#  <matplotlib.lines.Line2D at 0x210ab193d60>,
#  <matplotlib.lines.Line2D at 0x210ab193e50>,
#  <matplotlib.lines.Line2D at 0x210ab193f40>,
#  <matplotlib.lines.Line2D at 0x210ab1b0070>,
#  <matplotlib.lines.Line2D at 0x210ab1b0160>,
#  <matplotlib.lines.Line2D at 0x210ab1b0250>,
#  <matplotlib.lines.Line2D at 0x210ab1b0340>,
#  <matplotlib.lines.Line2D at 0x210ab1b0430>,
#  <matplotlib.lines.Line2D at 0x210ab1b0520>,
#  <matplotlib.lines.Line2D at 0x210ab1b0610>,
#  <matplotlib.lines.Line2D at 0x210ab1b0700>,
#  <matplotlib.lines.Line2D at 0x210ab1b07f0>,
#  <matplotlib.lines.Line2D at 0x210ab1b08e0>,
#  <matplotlib.lines.Line2D at 0x210ab1b09d0>,
#  <matplotlib.lines.Line2D at 0x210ab1b0ac0>,
#  <matplotlib.lines.Line2D at 0x210ab1b0bb0>,
#  <matplotlib.lines.Line2D at 0x210ab1b0ca0>,
#  <matplotlib.lines.Line2D at 0x210ab1b0d90>,
#  <matplotlib.lines.Line2D at 0x210ab1b0e80>,
#  <matplotlib.lines.Line2D at 0x210ab1b0f70>,
#  <matplotlib.lines.Line2D at 0x210ab1b1060>,
#  <matplotlib.lines.Line2D at 0x210ab1b1150>,
#  <matplotlib.lines.Line2D at 0x210ab1b1240>,
#  <matplotlib.lines.Line2D at 0x210ab1b1330>,
#  <matplotlib.lines.Line2D at 0x210ab1b1420>,
#  <matplotlib.lines.Line2D at 0x210ab1b1510>,
#  <matplotlib.lines.Line2D at 0x210ab1b1600>,
#  <matplotlib.lines.Line2D at 0x210ab1b16f0>,
#  <matplotlib.lines.Line2D at 0x210ab1b17e0>,
#  <matplotlib.lines.Line2D at 0x210ab1b18d0>,
#  <matplotlib.lines.Line2D at 0x210ab1b19c0>,
#  <matplotlib.lines.Line2D at 0x210ab1b1ab0>,
#  <matplotlib.lines.Line2D at 0x210ab1b1ba0>,
#  <matplotlib.lines.Line2D at 0x210ab1b1c90>,
#  <matplotlib.lines.Line2D at 0x210ab1b1d80>,
#  <matplotlib.lines.Line2D at 0x210ab1b1e70>,
#  <matplotlib.lines.Line2D at 0x210ab1b1f60>,
#  <matplotlib.lines.Line2D at 0x210ab1b2050>,
#  <matplotlib.lines.Line2D at 0x210ab1b2140>,
#  <matplotlib.lines.Line2D at 0x210ab1b2230>,
#  <matplotlib.lines.Line2D at 0x210ab1b2320>,
#  <matplotlib.lines.Line2D at 0x210ab1b2410>,
#  <matplotlib.lines.Line2D at 0x210ab1b2500>,
#  <matplotlib.lines.Line2D at 0x210ab1b25f0>,
#  <matplotlib.lines.Line2D at 0x210ab1b26e0>,
#  <matplotlib.lines.Line2D at 0x210ab1b27d0>,
#  <matplotlib.lines.Line2D at 0x210ab1b28c0>,
#  <matplotlib.lines.Line2D at 0x210ab1b29b0>,
#  <matplotlib.lines.Line2D at 0x210ab1b2aa0>,
#  <matplotlib.lines.Line2D at 0x210ab1b2b90>]

# %%
# temp = torch.from_numpy(vols)
temp.unsqueeze(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # temp = torch.from_numpy(vols)
# ----> 2 temp.unsqueeze(0)
#
# NameError: name 'temp' is not defined

# %%
prob_atlas = np.load('data/prob_atlas.npz')
prob_atlas = np.array(prob_atlas['vol_data'])
prob_atlas.shape
# Out:
# (160, 192, 224, 42)

# %%
all_np.reshape(-1).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 all_np.reshape(-1).shape
#
# NameError: name 'all_np' is not defined

# %%
np.count_nonzero(data_np)
# Out:
# 1553825
